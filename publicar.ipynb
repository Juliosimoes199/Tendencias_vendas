# %%
from IPython.display import Image, display

# %% [markdown]
# # Tendência de Vendas

# %%
display(Image(filename='R.jpeg',  height=600))

# %%
import pandas as pd

# %%
df = pd.read_csv('tendencias1.csv')

# %%
df.head() # Visualizando as 5 primeiras linhas do arquivo
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %%
df.shape # Configuração do Arquivo (3900 linhas por 19 colunas)
# Out:
# (3900, 19)

# %%
df.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Payment Method',
#        'Shipping Type', 'Discount Applied', 'Promo Code Used',
#        'Previous Purchases', 'Preferred Payment Method',
#        'Frequency of Purchases'],
#       dtype='object')

# %%
# Renomeando as colunas
df.columns = ['ID do cliente', 'Idade', 'Sexo', 'Item comprado', 'Categoria','Valor da compra (USD)', 'Localização', 'Tamanho', 'Cor', 'Estação',
       'Classificação de avaliação', 'Status da assinatura', 'Método de pagamento',
       'Tipo de envio', 'Desconto aplicado', 'Código promocional usado',
       'Compras Anteriores', 'Método de Pagamento Preferido',
       'Frequência de compras']

# %%
df.head()
# Out:
#    ID do cliente  Idade  Sexo Item comprado Categoria  Valor da compra (USD)  \
# 0              1     55  Male        Blouse  Clothing                     53
# 1              2     19  Male       Sweater  Clothing                     64
# 2              3     50  Male         Jeans  Clothing                     73
# 3              4     21  Male       Sandals  Footwear                     90
# 4              5     45  Male        Blouse  Clothing                     49
#
#      Localização Tamanho        Cor Estação  Classificação de avaliação  \
# 0       Kentucky       L       Gray  Winter                         3.1
# 1          Maine       L     Maroon  Winter                         3.1
# 2  Massachusetts       S     Maroon  Spring                         3.1
# 3   Rhode Island       M     Maroon  Spring                         3.5
# 4         Oregon       M  Turquoise  Spring                         2.7
#
# ...

# %%
df.info() # Informações das colunas
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 19 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   ID do cliente                  3900 non-null   int64
#  1   Idade                          3900 non-null   int64
#  2   Sexo                           3900 non-null   object
#  3   Item comprado                  3900 non-null   object
#  4   Categoria                      3900 non-null   object
#  5   Valor da compra (USD)          3900 non-null   int64
#  6   Localização                    3900 non-null   object
#  7   Tamanho                        3900 non-null   object
#  8   Cor                            3900 non-null   object
#  9   Estação                        3900 non-null   object
#  10  Classificação de avaliação     3900 non-null   float64
#  11  Status da assinatura           3900 non-null   object
# ...

# %% [markdown]
# # O que os clientes mais têm comprado por categoria

# %%
import seaborn as sns
import plotly.express as px

# %%
df['Categoria'].unique()
# Out:
# array(['Clothing', 'Footwear', 'Outerwear', 'Accessories'], dtype=object)

# %%
sns.histplot(df['Categoria'])
# Out:
# <Axes: xlabel='Categoria', ylabel='Count'>

# %% [markdown]
# # Analisando produtos em relação a cor

# %%
cor = df[['Categoria', 'Cor']]

# %%
cor[cor['Categoria'] == 'Clothing'].value_counts().sort_values(ascending=False)
# Out:
# Categoria  Cor
# Clothing   Teal         84
#            Maroon       83
#            Black        81
#            Silver       80
#            Violet       79
#            Green        78
#            Orange       78
#            Cyan         76
#            Yellow       75
#            Pink         73
#            Charcoal     73
#            Purple       72
#            White        69
#            Red          68
#            Peach        65
#            Turquoise    65
#            Beige        65
#            Gray         62
#            Gold         62
#            Olive        61
#            Brown        61
#            Lavender     60
#            Indigo       59
#            Magenta      59
#            Blue         49
# Name: count, dtype: int64

# %% [markdown]
# # As cores de vestuarios que mais são vendidos: Teal, Maroon, Black, Silver, Violet

# %%
cor[cor['Categoria'] == 'Accessories'].value_counts().sort_values(ascending=False)
# Out:
# Categoria    Cor
# Accessories  Olive        66
#              Blue         59
#              Gray         59
#              Magenta      58
#              Peach        58
#              Yellow       56
#              Charcoal     55
#              Red          54
#              Green        53
#              Indigo       52
#              Black        51
#              Silver       51
#              Turquoise    50
#              Lavender     49
#              Cyan         47
#              Teal         47
#              Beige        44
#              Orange       44
#              Brown        44
#              Gold         41
#              Violet       41
#              White        41
#              Maroon       41
#              Purple       40
#              Pink         39
# Name: count, dtype: int64

# %% [markdown]
# # Cor de acessórios que mais são vendidos: Olive, Blue, Gray, Magenta, Peach

# %% [markdown]
# # Visualizar as categorias por sexo

# %%
sns.histplot(data=df, x='Categoria', hue='Sexo')
# Out:
# <Axes: xlabel='Categoria', ylabel='Count'>

# %% [markdown]
# # Lucros por sexo

# %%
df[['Sexo', 'Valor da compra (USD)']].groupby('Sexo').sum().style.background_gradient(cmap='Blues', axis=None)
# Out:
# <style type="text/css">
# #T_11be2_row0_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_11be2_row1_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_11be2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_11be2_level0_col0" class="col_heading level0 col0" >Valor da compra (USD)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Sexo</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_11be2_level0_row0" class="row_heading level0 row0" >Female</th>
#       <td id="T_11be2_row0_col0" class="data row0 col0" >75191</td>
#     </tr>
#     <tr>
#       <th id="T_11be2_level0_row1" class="row_heading level0 row1" >Male</th>
#       <td id="T_11be2_row1_col0" class="data row1 col0" >157890</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Quantos homens e mulheres temos na nossa base

# %%
df['Sexo'].value_counts()
# 68% são homens(2652) / 32% são mulheres(1248)
# Out:
# Sexo
# Male      2652
# Female    1248
# Name: count, dtype: int64

# %% [markdown]
# # Não aplicamos descontos a nenhuma mulher

# %%
sns.histplot(data=df, x='Desconto aplicado', hue='Sexo')
# Out:
# <Axes: xlabel='Desconto aplicado', ylabel='Count'>

# %% [markdown]
# # Não fornecemos nenhum código promocial a nenhuma mulher

# %%
sns.histplot(data=df, x='Código promocional usado', hue='Sexo')
# Out:
# <Axes: xlabel='Código promocional usado', ylabel='Count'>

# %% [markdown]
# # Método de pagamento preferido

# %%
fig3=  px.histogram(df, y='Método de Pagamento Preferido')
fig3.show()
# Out:
# <div>                            <div id="cd94e91b-2164-416d-ac85-5ddc232fb2aa" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cd94e91b-2164-416d-ac85-5ddc232fb2aa")) {                    Plotly.newPlot(                        "cd94e91b-2164-416d-ac85-5ddc232fb2aa",                        [{"alignmentgroup":"True","bingroup":"y","hovertemplate":"count=%{x}\u003cbr\u003eM\u00e9todo de Pagamento Preferido=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"xaxis":"x","y":["Venmo","Cash","Credit Card","PayPal","PayPal","Venmo","Cash","Credit Card","Venmo","Cash","Bank Transfer","Bank Transfer","Venmo","PayPal","Debit Card","P
# ...

# %% [markdown]
# # Com base as análises posso concluir que gerar códigos promocional e descontos as mulheres pode ser um bom método para aumentar o lucro da empresa, olhando no sentido de que todo mundo gosta de pagar um pouquinho a menos por um produto ou serviço e só os homens estão a ter esses desconto e as mulheres estão a fica de parte
